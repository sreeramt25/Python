# %%
import pandas as pd

# %%
#TASK1
ID = pd.Series(["A001","A002","A003","A004","A005"])
Project = pd.Series(["Project 1","Project 2","Project 3","Project 4","Project 5","Project 6","Project 7","Project 8","Project 9","Project 10",
                     "Project 11","Project 12","Project 13","Project 14"])
Cost = pd.Series([1002000,2000000,4500000,5500000,"",680000,400000,350000,"",300000,2000000,1000000,3000000,200000])
Status = pd.Series(["Finished","Ongoing","Finished","Ongoing","Finished","Failed","Finished","Failed","Ongoing","Finished","Failed",
                    "Ongoing","Finished","Finished" ])
Project_Dataframe = pd.DataFrame({"ID":pd.Series(['A001','A002','A003','A004','A005', 'A002', 'A005', 'A003', 'A001', 'A003', 'A001','A004', 'A004', 'A005']),
                                                 "Project":Project,"Cost":Cost,"Status":Status})
#Create a dataframe based on the given data

# %%
Project_Dataframe.to_csv('C:/python project/Project_Dataframe.csv', index=False) #Save as a csv file

# %%
loaded_Project_Dataframe = pd.read_csv('C:/python project/Project_Dataframe.csv') # Read the csv file

# %%
loaded_Project_Dataframe
# Out:
#       ID     Project       Cost    Status
# 0   A001   Project 1  1002000.0  Finished
# 1   A002   Project 2  2000000.0   Ongoing
# 2   A003   Project 3  4500000.0  Finished
# 3   A004   Project 4  5500000.0   Ongoing
# 4   A005   Project 5        NaN  Finished
# 5   A002   Project 6   680000.0    Failed
# 6   A005   Project 7   400000.0  Finished
# 7   A003   Project 8   350000.0    Failed
# 8   A001   Project 9        NaN   Ongoing
# 9   A003  Project 10   300000.0  Finished
# 10  A001  Project 11  2000000.0    Failed
# 11  A004  Project 12  1000000.0   Ongoing
# 12  A004  Project 13  3000000.0  Finished
# 13  A005  Project 14   200000.0  Finished

# %%
Name = pd.Series(["John Alter","Alice Luxumberg","Tom Sabestine","Nina Adgra","Amy Johny"])
Gender = pd.Series(["M","F","M","F","F"])
City = pd.Series(["Paris","London","Berlin","New York","Madrid"])
Age = pd.Series([25,27,29,31,30])
Employee_DataFrame = pd.DataFrame({"ID":ID,"Name":Name,"Gender":Gender,"City":City,"Age":Age})
#Create a dataframe based on the given data

# %%
Employee_DataFrame.to_csv('C:/python project/Employee_Dataframe.csv', index=False) #Save as a csv file

# %%
loaded_Employee_DataFrame = pd.read_csv('C:/python project/Employee_Dataframe.csv') # Read the csv file

# %%
loaded_Employee_DataFrame
# Out:
#      ID             Name Gender      City  Age
# 0  A001       John Alter      M     Paris   25
# 1  A002  Alice Luxumberg      F    London   27
# 2  A003    Tom Sabestine      M    Berlin   29
# 3  A004       Nina Adgra      F  New York   31
# 4  A005        Amy Johny      F    Madrid   30

# %%
Designation_level = pd.Series([2,2,3,2,3])
Seniority_levelDF = pd.DataFrame({"ID":ID,"Designation_level":Designation_level}) #Create a dataframe based on the given data

# %%
Seniority_levelDF.to_csv('C:/python project/Seniority_levelDF.csv', index=False) #Save as a csv file

# %%
loaded_Seniority_levelDF = pd.read_csv('C:/python project/Seniority_levelDF.csv') # Read the csv file

# %%
loaded_Seniority_levelDF
# Out:
#      ID  Designation_level
# 0  A001                  2
# 1  A002                  2
# 2  A003                  3
# 3  A004                  2
# 4  A005                  3

# %%
#Task 2

# %%
loaded_Project_Dataframe = pd.read_csv('C:/python project/Project_Dataframe.csv') = pd.read_csv('C:/python project/Project_Dataframe.csv') # Read the csv file

# %%
loaded_Project_Dataframe
# Out:
#       ID     Project       Cost    Status
# 0   A001   Project 1  1002000.0  Finished
# 1   A002   Project 2  2000000.0   Ongoing
# 2   A003   Project 3  4500000.0  Finished
# 3   A004   Project 4  5500000.0   Ongoing
# 4   A005   Project 5        NaN  Finished
# 5   A002   Project 6   680000.0    Failed
# 6   A005   Project 7   400000.0  Finished
# 7   A003   Project 8   350000.0    Failed
# 8   A001   Project 9        NaN   Ongoing
# 9   A003  Project 10   300000.0  Finished
# 10  A001  Project 11  2000000.0    Failed
# 11  A004  Project 12  1000000.0   Ongoing
# 12  A004  Project 13  3000000.0  Finished
# 13  A005  Project 14   200000.0  Finished

# %%
# Initialize the running average
running_average = 0

# Calculate the running average for the 'Cost' column
for i in range(len(loaded_Project_Dataframe)):
    if pd.notna(loaded_Project_Dataframe.loc[i, 'Cost']):
        running_average = (running_average * i + loaded_Project_Dataframe.loc[i, 'Cost']) / (i + 1)
    else:
        loaded_Project_Dataframe.loc[i, 'Cost'] = running_average
loaded_Project_Dataframe
# Out:
#       ID     Project       Cost    Status
# 0   A001   Project 1  1002000.0  Finished
# 1   A002   Project 2  2000000.0   Ongoing
# 2   A003   Project 3  4500000.0  Finished
# 3   A004   Project 4  5500000.0   Ongoing
# 4   A005   Project 5  3250500.0  Finished
# 5   A002   Project 6   680000.0    Failed
# 6   A005   Project 7   400000.0  Finished
# 7   A003   Project 8   350000.0    Failed
# 8   A001   Project 9  2210312.5   Ongoing
# 9   A003  Project 10   300000.0  Finished
# 10  A001  Project 11  2000000.0    Failed
# 11  A004  Project 12  1000000.0   Ongoing
# 12  A004  Project 13  3000000.0  Finished
# 13  A005  Project 14   200000.0  Finished

# %%
Running_avg_df = loaded_Project_Dataframe.copy() # copying it to 'Running_avg_df'

# %%
Running_avg_df.to_csv('C:/python project/Running_avg_df.csv', index=False) #Save as a csv file

# %%
loaded_Running_avg_df = pd.read_csv('C:/python project/Running_avg_df.csv') #Read the csv file

# %%
#Task 3

# %%
loaded_Employee_DataFrame = pd.read_csv('C:/python project/Employee_Dataframe.csv') #Read the csv file

# %%
df1=loaded_Employee_DataFrame.copy()  # copying it to 'df1'

# %%
# split the names into first name and last name
df1["First Name"] = df1["Name"].str.split(" ").str[0]
df1["Last Name"] = df1["Name"].str.split(" ").str[1]

# remove the original name column
df1_rem = df1.drop("Name", axis=1)

# %%
df1_rem
# Out:
#      ID Gender      City  Age First Name  Last Name
# 0  A001      M     Paris   25       John      Alter
# 1  A002      F    London   27      Alice  Luxumberg
# 2  A003      M    Berlin   29        Tom  Sabestine
# 3  A004      F  New York   31       Nina      Adgra
# 4  A005      F    Madrid   30        Amy      Johny

# %%
df1_rem.to_csv('C:/python project/df1.csv', index=False) #Save as a csv file

# %%
loaded_df1 = pd.read_csv('C:/python project/df1.csv') #Read the csv file
# Out:
#      ID Gender      City  Age First Name  Last Name
# 0  A001      M     Paris   25       John      Alter
# 1  A002      F    London   27      Alice  Luxumberg
# 2  A003      M    Berlin   29        Tom  Sabestine
# 3  A004      F  New York   31       Nina      Adgra
# 4  A005      F    Madrid   30        Amy      Johny

# %%
# Task4

# %%
loaded_df1 = pd.read_csv('C:/python project/df1.csv') #Read the csv file

# %%
task4 = loaded_df1.copy() # copying it to 'task4'

# %%
merge1 = pd.merge(loaded_df1,loaded_Seniority_levelDF,on = 'ID') #merging the datafarme

# %%
merge1
# Out:
#      ID Gender      City  Age First Name  Last Name  Designation_level
# 0  A001      M     Paris   25       John      Alter                  2
# 1  A002      F    London   27      Alice  Luxumberg                  2
# 2  A003      M    Berlin   29        Tom  Sabestine                  3
# 3  A004      F  New York   31       Nina      Adgra                  2
# 4  A005      F    Madrid   30        Amy      Johny                  3

# %%
loaded_Running_avg_df = pd.read_csv('C:/python project/Running_avg_df.csv')  #Read the csv file

# %%
Final_merge = pd.merge(loaded_Running_avg_df,merge1, on = 'ID') #merging the datafarme

# %%
Final_merge
# Out:
#       ID     Project       Cost    Status Gender      City  Age First Name  \
# 0   A001   Project 1  1002000.0  Finished      M     Paris   25       John
# 1   A001   Project 9  2210312.5   Ongoing      M     Paris   25       John
# 2   A001  Project 11  2000000.0    Failed      M     Paris   25       John
# 3   A002   Project 2  2000000.0   Ongoing      F    London   27      Alice
# 4   A002   Project 6   680000.0    Failed      F    London   27      Alice
# 5   A003   Project 3  4500000.0  Finished      M    Berlin   29        Tom
# 6   A003   Project 8   350000.0    Failed      M    Berlin   29        Tom
# 7   A003  Project 10   300000.0  Finished      M    Berlin   29        Tom
# 8   A004   Project 4  5500000.0   Ongoing      F  New York   31       Nina
# 9   A004  Project 12  1000000.0   Ongoing      F  New York   31       Nina
# 10  A004  Project 13  3000000.0  Finished      F  New York   31       Nina
# ...

# %%
Final_merge.to_csv('C:/python project/Final_merge.csv', index=False) #Save as csv file

# %%
loaded_Final_merge = pd.read_csv('C:/python project/Final_merge.csv') #Read the csv file

# %%
#Task 5

# %%
loaded_Final_merge = pd.read_csv('C:/python project/Final_merge.csv') #Read the csv file

# %%
empty = []
# Iterate over each row in the loaded_Final_merge DataFrame
for i,r in loaded_Final_merge.iterrows():
    # Check if the status of the project is "Finished"
    if r['Status'] == "Finished":
         # If finished, apply a 5% increase to the cost
        result = r['Cost'] * 1.05
        empty.append(result)
    else:  
        # If not finished, keep the cost unchange
        result = r['Cost']
        empty.append(result)

# %%
loaded_Final_merge.insert(3,"Bonus 5%",empty) # insert the column

# %%
Bonus=loaded_Final_merge.copy() # copy to 'Bonus'

# %%
Bonus
# Out:
#       ID     Project       Cost   Bonus 5%    Status Gender      City  Age  \
# 0   A001   Project 1  1002000.0  1052100.0  Finished      M     Paris   25
# 1   A001   Project 9  2210312.5  2210312.5   Ongoing      M     Paris   25
# 2   A001  Project 11  2000000.0  2000000.0    Failed      M     Paris   25
# 3   A002   Project 2  2000000.0  2000000.0   Ongoing      F    London   27
# 4   A002   Project 6   680000.0   680000.0    Failed      F    London   27
# 5   A003   Project 3  4500000.0  4725000.0  Finished      M    Berlin   29
# 6   A003   Project 8   350000.0   350000.0    Failed      M    Berlin   29
# 7   A003  Project 10   300000.0   315000.0  Finished      M    Berlin   29
# 8   A004   Project 4  5500000.0  5500000.0   Ongoing      F  New York   31
# 9   A004  Project 12  1000000.0  1000000.0   Ongoing      F  New York   31
# 10  A004  Project 13  3000000.0  3150000.0  Finished      F  New York   31
# ...

# %%
Bonus.to_csv('C:/python project/Bonus.csv', index=False) #Save as csv file

# %%
loaded_Bonus = pd.read_csv('C:/python project/Bonus.csv') #Read the csv file

# %%
Bonus1 = loaded_Bonus.copy() # copy to 'Bonus1'

# %%
Bonus1
# Out:
#       ID     Project       Cost   Bonus 5%    Status Gender      City  Age  \
# 0   A001   Project 1  1002000.0  1052100.0  Finished      M     Paris   25
# 1   A001   Project 9  2210312.5  2210312.5   Ongoing      M     Paris   25
# 2   A001  Project 11  2000000.0  2000000.0    Failed      M     Paris   25
# 3   A002   Project 2  2000000.0  2000000.0   Ongoing      F    London   27
# 4   A002   Project 6   680000.0   680000.0    Failed      F    London   27
# 5   A003   Project 3  4500000.0  4725000.0  Finished      M    Berlin   29
# 6   A003   Project 8   350000.0   350000.0    Failed      M    Berlin   29
# 7   A003  Project 10   300000.0   315000.0  Finished      M    Berlin   29
# 8   A004   Project 4  5500000.0  5500000.0   Ongoing      F  New York   31
# 9   A004  Project 12  1000000.0  1000000.0   Ongoing      F  New York   31
# 10  A004  Project 13  3000000.0  3150000.0  Finished      F  New York   31
# ...

# %%
Bonus1.to_csv('C:/python project/Bonus1.csv', index=False)  #Save as csv file

# %%
loaded_Bonus1 = pd.read_csv('C:/python project/Bonus1.csv') #Read the csv file

# %%
#Task 6

# %%
loaded_Bonus1 = pd.read_csv('C:/python project/Bonus1.csv') #Read the csv file

# %%
 loaded_Bonus1.loc[loaded_Bonus1['Status'] == 'Failed', 'Designation_level'] -= 1
# Decrease the designation level by 1 for employees with a 'Failed' status in the Bonus1 DataFrame

# %%
df_filtered1 = loaded_Bonus1[loaded_Bonus1['Designation_level'] > 4]
# Filter the loaded_Bonus1 DataFrame to include only rows where 'Designation_level' is greater than 4

# %%
Des_red=loaded_Bonus1.copy() # copy to 'Des_red'

# %%
Des_red.to_csv('C:/python project/Des_red.csv', index=False)  #Save as csv file

# %%
loaded_Des_red = pd.read_csv('C:/python project/Des_red.csv')#Read the csv file

# %%
loaded_Des_red
# Out:
#       ID     Project       Cost   Bonus 5%    Status Gender      City  Age  \
# 0   A001   Project 1  1002000.0  1052100.0  Finished      M     Paris   25
# 1   A001   Project 9  2210312.5  2210312.5   Ongoing      M     Paris   25
# 2   A001  Project 11  2000000.0  2000000.0    Failed      M     Paris   25
# 3   A002   Project 2  2000000.0  2000000.0   Ongoing      F    London   27
# 4   A002   Project 6   680000.0   680000.0    Failed      F    London   27
# 5   A003   Project 3  4500000.0  4725000.0  Finished      M    Berlin   29
# 6   A003   Project 8   350000.0   350000.0    Failed      M    Berlin   29
# 7   A003  Project 10   300000.0   315000.0  Finished      M    Berlin   29
# 8   A004   Project 4  5500000.0  5500000.0   Ongoing      F  New York   31
# 9   A004  Project 12  1000000.0  1000000.0   Ongoing      F  New York   31
# 10  A004  Project 13  3000000.0  3150000.0  Finished      F  New York   31
# ...

# %%
#Task7

# %%
loaded_Des_red = pd.read_csv('C:/python project/Des_red.csv')#read the csv file

# %%
loaded_Des_red['First Name'] = loaded_Des_red.apply(lambda x: "Mr. " + x['First Name'] if x['Gender'] == "M" else "Mrs. " + x['First Name'], axis=1)
# Add a salutation to the 'First Name' based on the 'Gender' column

# %%
drop1 = loaded_Des_red.drop(columns = ['Gender'],index = 1) # drop the 'Gender' column

# %%
drop1
# Out:
#       ID     Project       Cost   Bonus 5%    Status      City  Age  \
# 0   A001   Project 1  1002000.0  1052100.0  Finished     Paris   25
# 2   A001  Project 11  2000000.0  2000000.0    Failed     Paris   25
# 3   A002   Project 2  2000000.0  2000000.0   Ongoing    London   27
# 4   A002   Project 6   680000.0   680000.0    Failed    London   27
# 5   A003   Project 3  4500000.0  4725000.0  Finished    Berlin   29
# 6   A003   Project 8   350000.0   350000.0    Failed    Berlin   29
# 7   A003  Project 10   300000.0   315000.0  Finished    Berlin   29
# 8   A004   Project 4  5500000.0  5500000.0   Ongoing  New York   31
# 9   A004  Project 12  1000000.0  1000000.0   Ongoing  New York   31
# 10  A004  Project 13  3000000.0  3150000.0  Finished  New York   31
# 11  A005   Project 5  3250500.0  3413025.0  Finished    Madrid   30
# 12  A005   Project 7   400000.0   420000.0  Finished    Madrid   30
# 13  A005  Project 14   200000.0   210000.0  Finished    Madrid   30
#
# ...

# %%
drop1.to_csv('C:/python project/drop1.csv', index=False)  #Save as csv file

# %%
loaded_drop1 = pd.read_csv('C:/python project/drop1.csv') #read the csv file

# %%
#Task 8

# %%
loaded_drop1 = pd.read_csv('C:/python project/drop1.csv') #read the csv file

# %%
# Iterate over each row in the loaded_drop1 DataFrame
for i, r in loaded_drop1.iterrows():
    # Check if the age of the employee is greater than 29
    if r["Age"] > 29:
        # If yes, increment the Designation_level by 1
        loaded_drop1.at[i, 'Designation_level'] += 1

# %%
loaded_drop1
# Out:
#       ID     Project       Cost   Bonus 5%    Status      City  Age  \
# 0   A001   Project 1  1002000.0  1052100.0  Finished     Paris   25
# 1   A001  Project 11  2000000.0  2000000.0    Failed     Paris   25
# 2   A002   Project 2  2000000.0  2000000.0   Ongoing    London   27
# 3   A002   Project 6   680000.0   680000.0    Failed    London   27
# 4   A003   Project 3  4500000.0  4725000.0  Finished    Berlin   29
# 5   A003   Project 8   350000.0   350000.0    Failed    Berlin   29
# 6   A003  Project 10   300000.0   315000.0  Finished    Berlin   29
# 7   A004   Project 4  5500000.0  5500000.0   Ongoing  New York   31
# 8   A004  Project 12  1000000.0  1000000.0   Ongoing  New York   31
# 9   A004  Project 13  3000000.0  3150000.0  Finished  New York   31
# 10  A005   Project 5  3250500.0  3413025.0  Finished    Madrid   30
# 11  A005   Project 7   400000.0   420000.0  Finished    Madrid   30
# 12  A005  Project 14   200000.0   210000.0  Finished    Madrid   30
#
# ...

# %%
Des_red1 = loaded_drop1.copy() # copy to 'Des_red1'

# %%
Des_red1.to_csv('C:/python project/Des_red1.csv', index=False) #Save as csv file

# %%
loaded_Des_red1 = pd.read_csv('C:/python project/Des_red1.csv') #read the csv file

# %%
# Task 9

# %%
loaded_Des_red1 = pd.read_csv('C:/python project/Des_red1.csv') #read the csv file

# %%
TotalProjCost = loaded_Des_red1.copy() # copy to 'TotalProjCost'

# %%
# Group the TotalProjCost DataFrame by 'ID' and 'First Name', calculate the sum of 'Cost' for each group, and reset the index
TotalProjCost = TotalProjCost.groupby(['ID', 'First Name'])['Cost'].sum().reset_index()

# Rename the columns of the TotalProjCost DataFrame
TotalProjCost.columns = ['ID', 'First Name', 'Total Cost']

# %%
TotalProjCost
# Out:
#      ID  First Name  Total Cost
# 0  A001    Mr. John   3002000.0
# 1  A002  Mrs. Alice   2680000.0
# 2  A003     Mr. Tom   5150000.0
# 3  A004   Mrs. Nina   9500000.0
# 4  A005    Mrs. Amy   3850500.0

# %%
TotalProjCost.to_csv('C:/python project/TotalProjCost.csv', index=False) #Save as csv file

# %%
loaded_TotalProjCost = pd.read_csv('C:/python project/TotalProjCost.csv') #read the csv file

# %%
# Task 10

# %%
loaded_Des_red1 = pd.read_csv('C:/python project/Des_red1.csv') #read the csv file

# %%
loaded_Des_red1
# Out:
#       ID     Project       Cost   Bonus 5%    Status      City  Age  \
# 0   A001   Project 1  1002000.0  1052100.0  Finished     Paris   25
# 1   A001  Project 11  2000000.0  2000000.0    Failed     Paris   25
# 2   A002   Project 2  2000000.0  2000000.0   Ongoing    London   27
# 3   A002   Project 6   680000.0   680000.0    Failed    London   27
# 4   A003   Project 3  4500000.0  4725000.0  Finished    Berlin   29
# 5   A003   Project 8   350000.0   350000.0    Failed    Berlin   29
# 6   A003  Project 10   300000.0   315000.0  Finished    Berlin   29
# 7   A004   Project 4  5500000.0  5500000.0   Ongoing  New York   31
# 8   A004  Project 12  1000000.0  1000000.0   Ongoing  New York   31
# 9   A004  Project 13  3000000.0  3150000.0  Finished  New York   31
# 10  A005   Project 5  3250500.0  3413025.0  Finished    Madrid   30
# 11  A005   Project 7   400000.0   420000.0  Finished    Madrid   30
# 12  A005  Project 14   200000.0   210000.0  Finished    Madrid   30
#
# ...

# %%
# Filter the loaded_Des_red1 DataFrame to include only rows where 'City' contains the letter "o"
filtered_employee_details = loaded_Des_red1[loaded_Des_red1['City'].str.contains('o')]

# %%
filtered_employee_details
# Out:
#      ID     Project       Cost   Bonus 5%    Status      City  Age  \
# 2  A002   Project 2  2000000.0  2000000.0   Ongoing    London   27
# 3  A002   Project 6   680000.0   680000.0    Failed    London   27
# 7  A004   Project 4  5500000.0  5500000.0   Ongoing  New York   31
# 8  A004  Project 12  1000000.0  1000000.0   Ongoing  New York   31
# 9  A004  Project 13  3000000.0  3150000.0  Finished  New York   31
#
#    First Name  Last Name  Designation_level
# 2  Mrs. Alice  Luxumberg                  2
# 3  Mrs. Alice  Luxumberg                  1
# 7   Mrs. Nina      Adgra                  3
# 8   Mrs. Nina      Adgra                  3
# 9   Mrs. Nina      Adgra                  3

# %%
filtered_employee_details.to_csv('C:/python project/filtered_employee_details.csv', index=False) #Save as csv file

# %%
loaded_filtered_employee_details = pd.read_csv('C:/python project/filtered_employee_details.csv') #read the csv file

# %%
loaded_filtered_employee_details
# Out:
#      ID     Project       Cost   Bonus 5%    Status      City  Age  \
# 0  A002   Project 2  2000000.0  2000000.0   Ongoing    London   27
# 1  A002   Project 6   680000.0   680000.0    Failed    London   27
# 2  A004   Project 4  5500000.0  5500000.0   Ongoing  New York   31
# 3  A004  Project 12  1000000.0  1000000.0   Ongoing  New York   31
# 4  A004  Project 13  3000000.0  3150000.0  Finished  New York   31
#
#    First Name  Last Name  Designation_level
# 0  Mrs. Alice  Luxumberg                  2
# 1  Mrs. Alice  Luxumberg                  1
# 2   Mrs. Nina      Adgra                  3
# 3   Mrs. Nina      Adgra                  3
# 4   Mrs. Nina      Adgra                  3
